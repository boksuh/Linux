# %% [markdown]
# # Ch.20 Regular Expressions
#
# ## What Are Regular Expressions?
#
# ### A definition
#
# ```
# A regular expression is a pattern template you define that a Linux utility uses to filter text.
# ```
#
# ### Types of regular expressions
#
# - The POSIX Basic Regular Expression engine
# - The POSIX Extended Regular Expression engine
#
# ---
#
# ## Defining BRE patterns
#
# ### Plain text
#
# ![image.png](attachment:image.png)
#
# ---
#
# ### Special characters
#
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# ### Anchor characters
#
# #### Starting at the beginning
#
# ![image-3.png](attachment:image-3.png)
#
# ---
#
# #### Looking for the ending
#
# ![image-4.png](attachment:image-4.png)
#
# ---
#
# #### Combining anchors
#
# ![image-5.png](attachment:image-5.png)
#
# ---
#
# ### The dot character
#
# ![image-6.png](attachment:image-6.png)
#
# - matches a single character
# - spaces are counted as character in regular expression
#
# ---
#
# ### Character classes
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ---
#
# ### Negating character classes
#
# ![image-9.png](attachment:image-9.png)
#
# ---
#
# ### Using ranges
#
# ![image-10.png](attachment:image-10.png)
#
# ---
#
# ### Special character classes
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# ---
#
# ### The asterisk
#
# ![image-13.png](attachment:image-13.png)
#
# ---
#
# ## Extended Regular Expressions
#
# ### The question mark
#
# ![image-14.png](attachment:image-14.png)
#
# ---
#
# ### The plus sign
#
# ![image-15.png](attachment:image-15.png)
#
# ---
#
# ### Using braces
#
# ![image-16.png](attachment:image-16.png)
#
# ---
#
# ### The pipe symbol
#
# ![image-17.png](attachment:image-17.png)
#
# ---
#
# ### Grouping expressions
#
# ![image-18.png](attachment:image-18.png)
#
# ---
#
# ## Regular Expressions in Action
#
# ### Counting directory files
#
# ![image-19.png](attachment:image-19.png)
#
# ---
#
# ### Validating a phone number
#
# ![image-20.png](attachment:image-20.png)
#
# ---
#
# ### Parsing an e-mail address
#
# ![image-21.png](attachment:image-21.png)
