# %% [markdown]
# # Doing Remote System Administration
#
#
# ## Doing Remote Login and Tunneling with SSH
#
# - telnet, ftp, rcp, rexec, rlogin
#
#
# ## Using Legacy Communications Tools
#
#  ![image.png](attachment:image.png)
#
#
# ### Configuring SSH
#
# - install openssh-server package
# - enabling X11 Tunneling lets you to have display of the client
#
#
# ### Logging in Remotely with ssh
#
# - ssh chris@myserver --> to login
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
#
# ### X11 Port Forwarding
#
# ![image-4.png](attachment:image-4.png)
# - Forwarding yes 확확인
#
#
# ### 서버 만들고 ssh 이용해서 접근하기
